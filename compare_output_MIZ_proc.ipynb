# %%
import xarray as xr
import numpy as np
import matplotlib.pyplot as plt

# %%
updated_miz_filter = '/cluster/projects/108541-SO-SIMBA/data_tmp/output_data/DA/product/icesat2/MIZ_filter_2/netcdf/v7/total_freeboard-sh-16fr-epsg6932_354_15-2026-07-01_10-01-59/2025/01/SOSIMBA-L3C-TFB-ATLAS_ICESAT2-SH_25KM_EASE2_DA-20250128-fv100.nc'
old_miz_filter = '/cluster/projects/108541-SO-SIMBA/data_tmp/output_data/DA/product/icesat2/MIZ_filter_2/netcdf/v7/tFB_2018_2025/2025/01/SOSIMBA-L3C-TFB-ATLAS_ICESAT2-SH_25KM_EASE2_DA-20250128-fv100.nc'
ds_new = xr.open_dataset(updated_miz_filter)
ds_old = xr.open_dataset(old_miz_filter)
# Out:
# /tmp/ipykernel_1523916/925116559.py:3: FutureWarning: In a future version, xarray will not decode the variable 'time_offset_acquisition' into a timedelta64 dtype based on the presence of a timedelta-like 'units' attribute by default. Instead it will rely on the presence of a timedelta64 'dtype' attribute, which is now xarray's default way of encoding timedelta64 values.
# To continue decoding into a timedelta64 dtype, either set `decode_timedelta=True` when opening this dataset, or add the attribute `dtype='timedelta64[ns]'` to this variable on disk.
# To opt-in to future behavior, set `decode_timedelta=False`.
#   ds_new = xr.open_dataset(updated_miz_filter)
# ...

# %%
(ds_new.total_freeboard-ds_old.total_freeboard).plot(vmin=-0.1, vmax=0.1, cmap='RdBu_r')
